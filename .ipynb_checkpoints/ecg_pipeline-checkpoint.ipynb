# %%
import neurokit2 as nk
import pandas as pd
from ecg_peak_editor import ECGPeakEditor
# %matplotlib widget

# %%
#import numpy as np
#corrected_r_peaks=np.load(r'C:\Users\lal\Documents\tez\analysis\r_peaks_edited_20241226_140954_578.npy')
#hr=nk.ecg_rate(corrected_r_peaks, sampling_rate=256)
#hrv_indices = nk.hrv(corrected_r_peaks, sampling_rate=256, show=False)

# %%
df=pd.read_csv(r"c:\Users\lal\Documents\tez\virtualreality_data_version1\578\virtual_reality\BBT-BIO-AAB024-2024-07-25_10-43-55\ExG [1].csv")
ecg_signal = ((df['ExG [1]-ch1']).to_numpy()) 
ecg_cleaned=nk.ecg_clean(ecg_signal, sampling_rate=256, method='neurokit')
r_peaks=nk.ecg_findpeaks(ecg_cleaned, sampling_rate=256)
r_peaks_info, r_peaks= nk.signal_fixpeaks(peaks=r_peaks, sampling_rate=256, interval_min=0.4,interval_max=1.5, method="neurokit")
#r_peaks = r_peaks['ECG_R_Peaks']
#r_peaks=np.load('r_peaks_edited.npy')
#r_peaks=np.load(r'C:\Users\lal\Documents\tez\analysis\r_peaks_edited_20241224_225853.npy')

# %%
r_peaks
# Out:
# array([   126,    269,    412, ..., 252237, 252404, 252572])

# %%
hr.mean()
# Out:
# np.float64(75.0574928446329)

# %%
hrv_indices
# Out:
#    HRV_MeanNN   HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  804.547156  65.759408   34.300798   54.158278   17.207243    62.23252
#
#    HRV_SDANN5  HRV_SDNNI5  HRV_RMSSD   HRV_SDSD  ...  HRV_SampEn  HRV_ShanEn  \
# 0   16.416475   62.680313  33.823484  33.840131  ...    0.983529    5.971521
#
#    HRV_FuzzyEn  HRV_MSEn  HRV_CMSEn  HRV_RCMSEn   HRV_CD   HRV_HFD   HRV_KFD  \
# 0     0.762172  1.539559   1.309788     1.96701  1.51776  1.619141  3.167662
#
#     HRV_LZC
# 0  0.537234
#
# [1 rows x 91 columns]

# %%
r_peaks_info
# Out:
# {'method': 'neurokit', 'extra': [], 'missed': []}

# %%
editor = ECGPeakEditor(signal=ecg_cleaned, 
                      r_peaks=r_peaks,
                      sampling_rate=256)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
corrected_r_peaks
# Out:
# array([   203,    402,    589, ..., 220419, 220620, 220818])
